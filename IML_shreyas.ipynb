# %%
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import os
import spacy
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import re
from bs4 import BeautifulSoup
from contractions import CONTRACTION_MAP
import unicodedata

# %%
nlp = spacy.load('en_core_web_lg', parse=True, tag=True, entity=True)
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
import sqlite3 as sq
conn = sq.Connection("news.db")

news_df =pd.read_sql("select * from news_table",conn)

# %%
news_df.head()
# Out:
#    id       published_date                                                url  \
# 0   1  2020-04-11T13:10:42  https://www.americanbankingnews.com/2020/04/11...
# 1   2  2020-04-11T23:00:00  https://www.itnews.com.au/news/vale-vista-the-...
# 2   3  2020-04-11T20:40:00  https://comicbook.com/gaming/2020/04/11/xbox-s...
# 3   4  2020-04-11T19:03:22  https://www.business-standard.com/article/news...
# 4   5  2020-04-11T18:08:29  https://menafn.com/1100009316/India-Microsoft-...
#
#                 outlet                                            content
# 0  americanbankingnews  Krueger & Catalano Capital Partners LLC grew i...
# 1               itnews  The thorn in <b>Microsofts</b> side will soon ...
# 2            comicbook  According to a new report, <b>Microsoft</b> wi...
# 3    business-standard  Read more about <b>Microsoft</b> Teams rolls o...
# 4               menafn  (MENAFN - NewsBytes) <b>Microsoft</b> has roll...

# %%
def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text()
    return stripped_text

def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text

def simple_stemmer(text):
    ps = nltk.porter.PorterStemmer()
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

def lemmatize_text(text):
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
def normalize_corpus(corpus, html_stripping=True, contraction_expansion=True,
                     accented_char_removal=True, text_lower_case=True, 
                     text_lemmatization=True, special_char_removal=True, 
                     stopword_removal=True, remove_digits=True):
    
    normalized_corpus = []
    # normalize each document in the corpus
    for doc in corpus:
        # strip HTML
        if html_stripping:
            doc = strip_html_tags(doc)
        # remove accented characters
        if accented_char_removal:
            doc = remove_accented_chars(doc)
        # expand contractions    
        if contraction_expansion:
            doc = expand_contractions(doc)
        # lowercase the text    
        if text_lower_case:
            doc = doc.lower()
        # remove extra newlines
        doc = re.sub(r'[\r|\n|\r\n]+', ' ',doc)
        # lemmatize text
        if text_lemmatization:
            doc = lemmatize_text(doc)
        # remove special characters and\or digits    
        if special_char_removal:
            # insert spaces between special characters to isolate them    
            special_char_pattern = re.compile(r'([{.(-)!}])')
            doc = special_char_pattern.sub(" \\1 ", doc)
            doc = remove_special_characters(doc, remove_digits=remove_digits)  
        # remove extra whitespace
        doc = re.sub(' +', ' ', doc)
        # remove stopwords
        if stopword_removal:
            doc = remove_stopwords(doc, is_lower_case=text_lower_case)
            
        normalized_corpus.append(doc)
        
    return normalized_corpus

# %%
news_df["clean_text"] = normalize_corpus(news_df["content"])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:357: UserWarning: "http://www.mesalliance.org/conferences/MicrosoftME-2017?speaker=Zach-LeBeau--SingularDTVhttp://www.mesalliance.org/conferences/MicrosoftME-2017?speaker=Zach-LeBeau--SingularDTV" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /opt/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:357: UserWarning: "https://www.cnbc.com/2019/03/12/stocks-making-the-biggest-moves-boeing-microsoft-tesla-amazon--more.htmlhttps://www.cnbc.com/2019/03/12/stocks-making-the-biggest-moves-boeing-microsoft-tesla-amazon--more.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
# create a basic pre-processed corpus, don't lowercase to get POS context
corpus = normalize_corpus(news_df['content'], text_lower_case=False, 
                          text_lemmatization=False, special_char_removal=False)

# demo for POS tagging for sample news headline
sentence = str(news_df.iloc[1].content)
sentence_nlp = nlp(sentence)

# POS tagging with Spacy 
spacy_pos_tagged = [(word, word.tag_, word.pos_) for word in sentence_nlp]
pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS tag', 'Tag type'])

# POS tagging with nltk
nltk_pos_tagged = nltk.pos_tag(sentence.split())
pd.DataFrame(nltk_pos_tagged, columns=['Word', 'POS tag'])
# Out:
#                   Word POS tag
# 0                  The      DT
# 1                thorn      NN
# 2                   in      IN
# 3    <b>Microsofts</b>      JJ
# 4                 side      NN
# ..                 ...     ...
# 170          Microsoft     NNP
# 171          Division,     NNP
# 172             wrote.      NN
# 173          Microsoft     NNP
# 174               heed      NN
#
# [175 rows x 2 columns]

# %%
from nltk.corpus import conll2000

data = conll2000.chunked_sents()
train_data = data[:10900]
test_data = data[10900:]

# %%
from nltk.chunk.util import tree2conlltags, conlltags2tree

wtc = tree2conlltags(train_data[1])

# %%
def conll_tag_chunks(chunk_sents):
    tagged_sents = [tree2conlltags(tree) for tree in chunk_sents]
    return [[(t, c) for (w, t, c) in sent] for sent in tagged_sents]


def combined_tagger(train_data, taggers, backoff=None):
    for tagger in taggers:
        backoff = tagger(train_data, backoff=backoff)
    return backoff

# %%
from nltk.tag import UnigramTagger, BigramTagger
from nltk.chunk import ChunkParserI

# define the chunker class
class NGramTagChunker(ChunkParserI):
    
  def __init__(self, train_sentences, 
               tagger_classes=[UnigramTagger, BigramTagger]):
    train_sent_tags = conll_tag_chunks(train_sentences)
    self.chunk_tagger = combined_tagger(train_sent_tags, tagger_classes)

  def parse(self, tagged_sentence):
    if not tagged_sentence: 
        return None
    pos_tags = [tag for word, tag in tagged_sentence]
    chunk_pos_tags = self.chunk_tagger.tag(pos_tags)
    chunk_tags = [chunk_tag for (pos_tag, chunk_tag) in chunk_pos_tags]
    wpc_tags = [(word, pos_tag, chunk_tag) for ((word, pos_tag), chunk_tag)
                     in zip(tagged_sentence, chunk_tags)]
    return conlltags2tree(wpc_tags)
  
# train chunker model  
ntc = NGramTagChunker(train_data)

# evaluate chunker model performance
print(ntc.evaluate(test_data))
# Out:
# ChunkParse score:
#     IOB Accuracy:  90.0%%
#     Precision:     82.1%%
#     Recall:        86.3%%
#     F-Measure:     84.1%%

# %%
chunk_tree = ntc.parse(nltk_pos_tagged)

# %%
from nltk.parse.stanford import StanfordParser

scp = StanfordParser(path_to_jar='stanford-parser-full-2015-04-20/stanford-parser.jar',
                     path_to_models_jar='stanford-parser-full-2015-04-20/stanford-parser-3.5.2-models.jar')
                   
result = list(scp.raw_parse(sentence))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: The StanfordParser will be deprecated
# Please use nltk.parse.corenlp.CoreNLPParser instead.
#   after removing the cwd from sys.path.

# %%
dependency_pattern = '{left}<---{word}[{w_type}]--->{right}\n--------'
for token in sentence_nlp:
    print(dependency_pattern.format(word=token.orth_, 
                                  w_type=token.dep_,
                                  left=[t.orth_ 
                                            for t 
                                            in token.lefts],
                                  right=[t.orth_ 
                                             for t 
                                             in token.rights]))
# Out:
# []<---The[det]--->[]
# --------
# ['The']<---thorn[nsubjpass]--->['in', '>']
# --------
# []<---in[prep]--->['Microsofts</b']
# --------
# []<---<[nmod]--->[]
# --------
# ['<']<---b[dep]--->[]
# --------
# ['b']<--->[nmod]--->[]
# --------
# ['>']<---Microsofts</b[pobj]--->[]
# --------
# []<--->[advmod]--->[]
# --------
# []<---side[nsubjpass]--->[]
# --------
# []<---will[aux]--->[]
# --------
# []<---soon[advmod]--->[]
# --------
# []<---be[auxpass]--->[]
# --------
# ['thorn', 'side', 'will', 'soon', 'be']<---laid[ROOT]--->['to', 'issued', '.']
# --------
# []<---to[prep]--->['Gates']
# --------
# []<---rest.edict[amod]--->[]
# --------
# []<---Bill[compound]--->[]
# --------
# ['rest.edict', 'Bill']<---Gates[pobj]--->[]
# --------
# []<---had[aux]--->[]
# --------
# ['had']<---issued[advcl]--->['apply']
# --------
# []<---to[aux]--->[]
# --------
# ['to']<---apply[xcomp]--->['to']
# --------
# []<---to[prep]--->['Vista']
# --------
# []<---Vista[pobj]--->[',', 'had']
# --------
# []<---,[punct]--->[]
# --------
# []<---which[nsubj]--->[]
# --------
# []<---simply[advmod]--->[]
# --------
# ['which', 'simply']<---had[relcl]--->['be']
# --------
# []<---to[aux]--->[]
# --------
# ['to']<---be[xcomp]--->['secure']
# --------
# []<---more[advmod]--->[]
# --------
# ['more']<---secure[acomp]--->['than']
# --------
# []<---than[prep]--->['XP']
# --------
# []<---Windows[compound]--->[]
# --------
# ['Windows']<---XP[pobj]--->[]
# --------
# []<---.[punct]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---Vista[compound]--->[]
# --------
# ['Vista']<---Incapable[ROOT]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---Ahead[nsubj]--->['of']
# --------
# []<---of[prep]--->['launch']
# --------
# []<---Vistas[compound]--->[]
# --------
# ['Vistas']<---launch[pobj]--->[',', 'Microsoft']
# --------
# []<---,[punct]--->[]
# --------
# []<---Microsoft[appos]--->['and', 'hardware']
# --------
# []<---and[cc]--->[]
# --------
# []<---hardware[conj]--->[]
# --------
# ['Ahead']<---partnersplugged[ROOT]--->['system', 'hard', '.']
# --------
# []<---the[det]--->[]
# --------
# []<---new[amod]--->[]
# --------
# []<---operating[compound]--->[]
# --------
# ['the', 'new', 'operating']<---system[dobj]--->[]
# --------
# []<---hard[advmod]--->[]
# --------
# []<---.[punct]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---They[nsubj]--->[]
# --------
# ['They']<---drummed[ROOT]--->['up', 'publicity', 'as']
# --------
# []<---up[prt]--->[]
# --------
# []<---publicity[dobj]--->['by']
# --------
# []<---by[prep]--->['PCs']
# --------
# []<---advertising[compound]--->[]
# --------
# ['advertising']<---PCs[pobj]--->[]
# --------
# []<---as[prep]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---Vista[compound]--->[]
# --------
# ['Vista']<---Capable[ROOT]--->['\n ', 'encourage', '.']
# --------
# []<---
#  []--->[]
# --------
# []<---to[aux]--->[]
# --------
# ['to']<---encourage[advcl]--->['sales']
# --------
# []<---sales[dobj]--->[]
# --------
# []<---.[punct]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---But[cc]--->[]
# --------
# []<---complaints[nsubj]--->[]
# --------
# []<---soon[advmod]--->[]
# --------
# ['But', 'complaints', 'soon']<---surfaced[ROOT]--->['found', '.']
# --------
# []<---when[advmod]--->[]
# --------
# []<---users[nsubj]--->[]
# --------
# ['when', 'users']<---found[advcl]--->['PCs', 'with', 'run']
# --------
# []<---their[poss]--->[]
# --------
# []<---new[amod]--->[]
# --------
# ['their', 'new']<---PCs[dobj]--->[]
# --------
# []<---with[prep]--->['mb']
# --------
# []<---512[nummod]--->[]
# --------
# ['512']<---mb[pobj]--->['of', 'and']
# --------
# []<---of[prep]--->['RAM']
# --------
# []<---RAM[pobj]--->[]
# --------
# []<---and[cc]--->[]
# --------
# []<---DirectXP[compound]--->[]
# --------
# ['DirectXP']<---graphics[nsubj]--->[]
# --------
# []<---could[aux]--->[]
# --------
# []<---only[advmod]--->[]
# --------
# ['graphics', 'could', 'only']<---run[ccomp]--->['version']
# --------
# []<---the[det]--->[]
# --------
# []<---most[advmod]--->[]
# --------
# ['most']<---stripped[amod]--->['down']
# --------
# []<---down[prt]--->[]
# --------
# ['the', 'stripped']<---version[dobj]--->['of']
# --------
# []<---of[prep]--->['system']
# --------
# []<---the[det]--->[]
# --------
# []<---operating[compound]--->[]
# --------
# ['the', 'operating']<---system[pobj]--->[',', 'Basic']
# --------
# []<---,[punct]--->[]
# --------
# []<---Vista[compound]--->[]
# --------
# []<---Home[compound]--->[]
# --------
# ['Vista', 'Home']<---Basic[appos]--->[]
# --------
# []<---.[punct]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---The[det]--->[]
# --------
# ['The']<---innovations[nsubj]--->['attracted', '-']
# --------
# []<---that[nsubj]--->[]
# --------
# ['that']<---attracted[relcl]--->['consumers', 'to']
# --------
# []<---consumers[dobj]--->[]
# --------
# []<---to[prep]--->['things']
# --------
# []<---the[det]--->[]
# --------
# []<---new[amod]--->[]
# --------
# []<---OS[compound]--->[]
# --------
# []<----[punct]--->[]
# --------
# ['the', 'new', 'OS', '-']<---things[pobj]--->['like']
# --------
# []<---like[prep]--->['interface']
# --------
# []<---the[det]--->[]
# --------
# []<---Aero[compound]--->[]
# --------
# ['Aero']<---user[compound]--->[]
# --------
# ['the', 'user']<---interface[pobj]--->['and', 'handful']
# --------
# []<---and[cc]--->[]
# --------
# []<---a[det]--->[]
# --------
# ['a']<---handful[conj]--->['of']
# --------
# []<---of[prep]--->['functions']
# --------
# []<---Media[compound]--->[]
# --------
# ['Media']<---functions[pobj]--->[]
# --------
# []<----[punct]--->[]
# --------
# []<---could[aux]--->[]
# --------
# []<---nt[neg]--->[]
# --------
# ['innovations', 'could', 'nt']<---run[ROOT]--->['on', '.']
# --------
# []<---on[prep]--->['PCs']
# --------
# []<---their[poss]--->[]
# --------
# ['their']<---PCs[pobj]--->[]
# --------
# []<---.[punct]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---Even[advmod]--->[]
# --------
# []<---Microsoft[nmod]--->[]
# --------
# []<---senior[amod]--->[]
# --------
# ['Even', 'Microsoft', 'senior']<---management[nsubj]--->[]
# --------
# ['management']<---realised[ROOT]--->['was', '.']
# --------
# []<---Vista[compound]--->[]
# --------
# ['Vista']<---Capable[nsubj]--->[]
# --------
# ['Capable']<---was[ccomp]--->['mistake']
# --------
# []<---a[det]--->[]
# --------
# []<---terrible[amod]--->[]
# --------
# ['a', 'terrible']<---mistake[attr]--->[]
# --------
# []<---.[punct]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---I[nsubj]--->[]
# --------
# []<---now[advmod]--->[]
# --------
# ['I', 'now']<---have[ROOT]--->['machine', ',', 'leaked', '.']
# --------
# []<---a[det]--->[]
# --------
# []<---US$[quantmod]--->[]
# --------
# ['US$']<---2100[nummod]--->[]
# --------
# []<---email[compound]--->[]
# --------
# ['a', '2100', 'email']<---machine[dobj]--->[]
# --------
# []<---,[punct]--->[]
# --------
# []<---leaked[conj]--->['emails']
# --------
# []<---emails[dobj]--->['from', 'read']
# --------
# []<---from[prep]--->[]
# --------
# []<---Microsoft[compound]--->[]
# --------
# []<---vice[compound]--->[]
# --------
# ['Microsoft', 'vice']<---president[compound]--->[]
# --------
# []<---Mike[compound]--->[]
# --------
# ['president', 'Mike']<---Nash[nsubj]--->[]
# --------
# ['Nash']<---read[relcl]--->[]
# --------
# []<---.[punct]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---We[nsubj]--->[]
# --------
# []<---really[advmod]--->[]
# --------
# ['We', 'really']<---botched[ROOT]--->['this', '.']
# --------
# []<---this[dobj]--->[]
# --------
# []<---.[punct]--->[]
# --------
# []<---You[nmod]--->[]
# --------
# ['You']<---guys[nsubj]--->[]
# --------
# ['guys']<---have[ccomp]--->['do']
# --------
# []<---to[aux]--->[]
# --------
# ['to']<---do[xcomp]--->['job', 'with']
# --------
# []<---a[det]--->[]
# --------
# []<---better[amod]--->[]
# --------
# ['a', 'better']<---job[dobj]--->[]
# --------
# []<---with[prep]--->['customers']
# --------
# []<---our[poss]--->[]
# --------
# ['our']<---customers[pobj]--->[',', 'Allchin']
# --------
# []<---,[punct]--->[]
# --------
# []<---Jim[compound]--->[]
# --------
# ['Jim']<---Allchin[appos]--->[',', 'veteran']
# --------
# []<---,[punct]--->[]
# --------
# []<---a[det]--->[]
# --------
# ['a']<---veteran[appos]--->['from']
# --------
# []<---from[prep]--->['days']
# --------
# []<---the[det]--->[]
# --------
# []<---very[advmod]--->[]
# --------
# ['very']<---earliest[amod]--->[]
# --------
# ['the', 'earliest']<---days[pobj]--->['of', 'at']
# --------
# []<---of[prep]--->['Windows']
# --------
# []<---Windows[pobj]--->[]
# --------
# []<---at[prep]--->['Division']
# --------
# []<---Microsoft[compound]--->[]
# --------
# ['Microsoft']<---Division[pobj]--->[]
# --------
# []<---,[punct]--->[]
# --------
# ['have', ',']<---wrote[ROOT]--->['.']
# --------
# []<---.[punct]--->['\n']
# --------
# []<---
# []--->[]
# --------
# []<---Microsoft[nsubj]--->[]
# --------
# ['Microsoft']<---heed[ROOT]--->[]
# --------

# %%
from spacy import displacy

displacy.render(sentence_nlp, jupyter=True, 
                options={'distance': 110,
                         'arrow_stroke': 2,
                         'arrow_width': 8})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="652befb1ada04864b5e2db30bc2f82d2-0" class="displacy" width="21170" height="852.0" direction="ltr" style="max-width: none; height: 852.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">thorn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">&lt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">b</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">Microsofts&lt;/b</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">side</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">soon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">laid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">rest.edict</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Bill</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">Gates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">issued</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">apply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">Vista,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">simply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">secure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="762.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">SCONJ</tspan>
# </te

# %%
from nltk.parse.stanford import StanfordDependencyParser
sdp = StanfordDependencyParser(path_to_jar='stanford-parser-full-2015-04-20/stanford-parser.jar',
                               path_to_models_jar='stanford-parser-full-2015-04-20/stanford-parser-3.5.2-models.jar')    

result = list(sdp.raw_parse(sentence))  

# print the dependency tree
dep_tree = [parse.tree() for parse in result][0]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: The StanfordDependencyParser will be deprecated
# Please use nltk.parse.corenlp.CoreNLPDependencyParser instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sentence = str(news_df.iloc[1].content)
sentence_nlp = nlp(sentence)

# print named entities in article
print([(word, word.ent_type_) for word in sentence_nlp if word.ent_type_])

# visualize named entities
displacy.render(sentence_nlp, style='ent', jupyter=True)
# Out:
# [(rest.edict, 'PERSON'), (Bill, 'PERSON'), (Gates, 'PERSON'), (Vista, 'ORG'), (Windows, 'PRODUCT'), (XP, 'PRODUCT'), (Vistas, 'PRODUCT'), (Microsoft, 'ORG'), (512, 'QUANTITY'), (mb, 'QUANTITY'), (RAM, 'ORG'), (DirectXP, 'ORG'), (graphics, 'ORG'), (Vista, 'ORG'), (Home, 'ORG'), (Basic, 'ORG'), (Aero, 'ORG'), (Media, 'ORG'), (Microsoft, 'ORG'), (Vista, 'ORG'), (2100, 'MONEY'), (Microsoft, 'ORG'), (Mike, 'PERSON'), (Nash, 'PERSON'), (Jim, 'PERSON'), (Allchin, 'PERSON'), (the, 'DATE'), (very, 'DATE'), (earliest, 'DATE'), (days, 'DATE'), (Microsoft, 'ORG'), (Division, 'ORG'), (Microsoft, 'ORG')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The thorn in &lt;b&gt;Microsofts&lt;/b&gt; side will soon be laid to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rest.edict Bill Gates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had issued to apply to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vista
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which simply had to be more secure than
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Windows XP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# .</br>Vista Incapable</br>Ahead of
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vistas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  launch,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and hardware partnersplugged the new operating system hard.</br>They drummed up publicity by advertising PCs as </br>Vista Capable</br> to encourage sales.</br>But complaints soon surfaced when users found their new PCs with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     512mb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RAM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DirectXP graphics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  could only run the most stripped down version of the operating system,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vista Home Basic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</br>The innovations that attracted consumers to the new OS - things like the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  user interface and a handful of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Media
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  functions - couldnt run on their PCs.</br>Even
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  senior management realised
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vista
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Capable was a terrible mistake.</br>I now have a US$
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  email machine, leaked emails from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vice president
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mike Nash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  read.</br>We really botched this. You guys have to do a better job with our customers,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jim Allchin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a veteran from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the very earliest days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of Windows at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft Division
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , wrote.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  heed</div></span>

# %%
named_entities = []
for sentence in corpus:
    temp_entity_name = ''
    temp_named_entity = None
    sentence = nlp(sentence)
    for word in sentence:
        term = word.text 
        tag = word.ent_type_
        if tag:
            temp_entity_name = ' '.join([temp_entity_name, term]).strip()
            temp_named_entity = (temp_entity_name, tag)
        else:
            if temp_named_entity:
                named_entities.append(temp_named_entity)
                temp_entity_name = ''
                temp_named_entity = None

entity_frame = pd.DataFrame(named_entities, 
                            columns=['Entity Name', 'Entity Type'])

# %%
top_entities = (entity_frame.groupby(by=['Entity Name', 'Entity Type'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))
top_entities.T.iloc[:,:15]
# Out:
#                      0         1           2         3        4         5  \
# Entity Name  Microsoft        10  Microsofts       one    first       two
# Entity Type        ORG  CARDINAL         ORG  CARDINAL  ORDINAL  CARDINAL
# Frequency        31404      3644        3333      2804     2022      1887
#
#                  6       7       8        9       10     11        12    13  \
# Entity Name  today  Amazon  Google  Windows    Excel  Apple       One  MSFT
# Entity Type   DATE     ORG     ORG  PRODUCT  PRODUCT    ORG  CARDINAL   ORG
# Frequency     1340    1307    1265     1099     1045   1027       927   914
#
#                    14
# Entity Name         2
# Entity Type  CARDINAL
# Frequency         838

# %%
# get the top named entity types
top_entities = (entity_frame.groupby(by=['Entity Type'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))
top_entities.T.iloc[:,:15]
# Out:
#                   0      1         2        3       4      5      6        7  \
# Entity Type     ORG   DATE  CARDINAL  PRODUCT  PERSON    GPE  MONEY  ORDINAL
# Frequency    119524  35887     31523    23483   21829  13121   5739     4255
#
#                 8        9           10    11    12    13     14
# Entity Type  NORP  PERCENT  WORK_OF_ART   FAC  TIME   LOC  EVENT
# Frequency    3220     3080         2669  2276  2264  1431   1323

# %%
l= news_df["published_date"]
for i in range(len(l)):
    l[i]= l[i][:10]
news_df["published_date"] = l
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from datetime import datetime
k=news_df.outlet.unique()
len(k)
# Out:
# 5658

# %%
k=news_df["outlet"].value_counts()

# %%
ll=[]
count=0
for i,j in k.items():
    if(j>10):
        count=count+1
        ll.append(i)

# %%
news_df = news_df[news_df.outlet.isin(ll)]
    
data = news_df.copy()

# %%
## text blob

from textblob import TextBlob

# compute sentiment scores (polarity) and labels
sentiment_scores_tb = [round(TextBlob(article).sentiment.polarity, 3) for article in news_df['clean_text']]
sentiment_category_tb = ['positive' if score > 0 
                             else 'negative' if score < 0 
                                 else 'neutral' 
                                     for score in sentiment_scores_tb]


news_df["sentiment_score"] = sentiment_scores_tb
news_df["sentiment_category"] = sentiment_category_tb

# %%
from afinn import Afinn
af = Afinn()

# compute sentiment scores (polarity) and labels
sentiment_scores = [af.score(article) for article in data["clean_text"]]
sentiment_category = ['positive' if score > 0 
                          else 'negative' if score < 0 
                              else 'neutral' 
                                  for score in sentiment_scores]
    
    
data["sentiment_score"]=sentiment_scores
data["sentiment_category"]= sentiment_category

# %%
dd = pd.DataFrame()
df= pd.DataFrame()

dd["published_date"] = data["published_date"]
dd["sentiment_score"] = data["sentiment_score"]

df["published_date"] = news_df["published_date"]
df["sentiment_score"] = news_df["sentiment_score"]

# %%
dd =dd.groupby(dd.published_date)
dd=dd.mean()
df =df.groupby(df.published_date)
df=df.mean()

# %%
#dd.to_sql("afinn_news_csv",conn)
#df.to_sql("text_blob_news_csv",conn)
