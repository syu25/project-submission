# %%
import pandas as pd
import numpy as np
import math as mt
import sklearn as sk1
import datetime as dt
import matplotlib.pyplot as plt
import math 
import seaborn as plt1
from sklearn.model_selection import train_test_split
import pickle
import matplotlib.pyplot as plt2

# !pip install missingpy
import missingpy as imput_helper
# Out:
# Requirement already satisfied: missingpy in /usr/local/lib/python3.6/dist-packages (0.2.0)

# %%
work_dat_notDead_large = pd.read_csv("work_dat_notDead_large-Final model specific.csv")

work_dat_notDead_large_backup = work_dat_notDead_large.copy()

work_dat_notDead_large = work_dat_notDead_large.loc[work_dat_notDead_large['InscClaimAmtReimbursed']>5000,:].copy()

# %%
work_dat_notDead_large = work_dat_notDead_large.drop(columns=['Unnamed: 0'], axis = 1)

# %%
fig, axis = plt.subplots(figsize=(30, 20.27))
ax = plt1.heatmap(ax=axis, data = work_dat_notDead_large.corr())
